# %% [markdown]
# # EX8-STREAM: Spark Structured Streaming
#
# Your assignment: complete the `TODO`'s and include also the **output of each cell**.
#
# #### You may need to read the [Structured Streaming API Documentation](https://spark.apache.org/docs/latest/api/python/reference/pyspark.ss/index.html) to complete this lab.

# %% [markdown]
# ### Step 1: **[PLAN A]** Start Spark Session

# %%
from pyspark.sql import SparkSession

try:
    spark.stop()
except NameError:
    print("SparkContext not defined")

    # cluster mode
spark = SparkSession.builder \
            .appName("Spark SQL basic example") \
            .master("spark://spark:7077") \
	    	.config("spark.jars.packages", "org.apache.hadoop:hadoop-aws:3.3.4") \
            .config("spark.hadoop.fs.s3a.endpoint", "http://minio:9000") \
            .config("spark.hadoop.fs.s3a.access.key", "pdm_minio") \
            .config("spark.hadoop.fs.s3a.secret.key", "pdm_minio") \
            .config("spark.hadoop.fs.s3a.path.style.access", "true") \
            .config("spark.hadoop.fs.s3a.impl", "org.apache.hadoop.fs.s3a.S3AFileSystem") \
            .config("spark.hadoop.fs.s3a.connection.ssl.enabled", "false") \
	    	.getOrCreate()

# %% [markdown]
# ### Step 1: **[PLAN B]** Start Spark Session

# %%
from pyspark.sql import SparkSession
Start
try:
    spark.stop()
except NameError:
    print("SparkContext not defined")
    

# local mode
spark = SparkSession.builder \
            .appName("Spark SQL basic example") \
            .master("local[*]") \
	    	.config("spark.some.config.option", "some-value") \
	    	.getOrCreate()
# Out:
# SparkContext not defined
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 25/05/13 00:34:52 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %% [markdown]
# ### Step 2: Static Dataframe of words

# %%
#words_df = spark.read.csv("s3a://public/100words.txt.gz") # plan A
words_df = spark.read.csv("data/100words.txt.gz") # plan B
words_df = words_df.withColumnRenamed("_c0", "word")
words_df.show()
# Out:
# +----------+
# |      word|
# +----------+
# |     apple|
# |     sunny|
# | bookshelf|
# |  computer|
# |     pizza|
# |    friend|
# |     happy|
# |    flower|
# |basketball|
# |       dog|
# |     beach|
# |  vacation|
# |     piano|
# |  elephant|
# |    coffee|
# |  sunshine|
# | butterfly|
# |  mountain|
# |    guitar|
# |       cat|
# +----------+
# only showing top 20 rows

# %% [markdown]
# ### Step 3: Get meaning for each word (use [Free Dictionary API](https://dictionaryapi.dev/))

# %%
from pyspark.sql.functions import *
import requests_ratelimiter

def get_word_meaning(word, session):
    url = f"https://api.dictionaryapi.dev/api/v2/entries/en/{word}"
    response = session.get(url)
    response.raise_for_status()  # Ensure the request was successful
    json_data = response.json()

    try:
        meaning = json_data[0]['meanings'][0]['definitions'][0]['definition']
    except:
        meaning = "__NOT_FOUND__"

    return meaning


try:
    words_with_meaning_df.cache()
    words_with_meaning_df.show()
except NameError:
    print("words_with_meaning_df not defined")
    meanings = []
    session = requests_ratelimiter.LimiterSession(per_second=1)
    for word in [r.word for r in words_df.collect()]:
        meanings.append((word, get_word_meaning(word, session)))
        print(word)
    words_with_meaning_df = spark.createDataFrame(meanings, ["word", "meaning"])
    words_with_meaning_df.cache()
    words_with_meaning_df.show()
# Out:
# words_with_meaning_df not defined
# apple
# sunny
# bookshelf
# computer
# pizza
# friend
# happy
# flower
# basketball
# dog
# beach
# vacation
# piano
# elephant
# coffee
# sunshine
# butterfly
# mountain
# guitar
# cat
# phone
# birthday
# gift
# school
# homework
# music
# swimming
# library
# science
# fiction
# poem
# tree
# bird
# water
# city
# park
# running
# jumping
# cycling
# sky
# cloud
# starfish
# ocean
# wave
# shell
# pearl
# snail
# speed
# racing
# winner
# treasure
# pirate
# shipwreck
# mermaid
# fish
# coral
# reef
# surfboard
# kayak
# paddle
# canoe
# tent
# camping
# marshmallow
# s'mores
# campfire
# sparkler
# firework
# dragonfly
# monarch
# milkshake
# ice cream
# cookie
# brownie
# sundae
# peanut butter
# jelly
# grape
# strawberry
# blueberry
# raspberry
# kiwi
# pineapple
# orange
# banana
# avocado
# lemon
# lime
# mint
# basil
# rosemary
# thyme
# oregano
# cinnamon
# nutmeg
# gingerbread
# hot chocolate
# marshmallow
# stuffing
# turkey
# +----------+--------------------+
# |      word|             meaning|
# +----------+--------------------+
# |     apple|A common, round f...|
# |     sunny|          A sunfish.|
# | bookshelf|A shelf or shelve...|
# |  computer|A person employed...|
# |     pizza|A baked Italian d...|
# |    friend|A person other th...|
# |     happy|A happy event, th...|
# |    flower|A colorful, consp...|
# |basketball|A sport in which ...|
# |       dog|A mammal, Canis f...|
# |     beach|The shore of a bo...|
# |  vacation|Freedom from some...|
# |     piano|A percussive keyb...|
# |  elephant|A mammal of the o...|
# |    coffee|A beverage made b...|
# |  sunshine|The direct rays, ...|
# | butterfly|A flying insect o...|
# |  mountain|An elevation of l...|
# |    guitar|A stringed musica...|
# |       cat|An animal of the ...|
# +----------+--------------------+
# only showing top 20 rows

# %% [markdown]
# ### Step 4: **[PLAN A]** Create a stream of sentences using existing socket stream (LAB)

# %%
words_stream = spark \
    .readStream.format("socket") \
    .option("host", "socketstreamserver") \
    .option("port", 12345) \
    .load()

# %% [markdown]
# ### Step 4: **[PLAN B]** Create a socket stream and create a stream of sentences from that (NOTEBOOK LOCAL)
#
# 1. Before running the cell below, start socket stream from existing script `hostdir/bin/cmd.sh` using a notebook terminal.
# 2. Make sure it is running properly.
# 3. Create a spark stream using the command below

# %%
words_stream = spark \
    .readStream.format("socket") \
    .option("host", "localhost") \
    .option("port", 12345) \
    .load()
# Out:
# 25/05/13 00:38:10 WARN TextSocketSourceProvider: The socket source should not be used for production applications! It does not support recovery.

# %% [markdown]
# ### Step 5: Start stream just to visualize some of its values (for 10 seconds)

# %%
words_stream_writer = words_stream.writeStream.format("console").outputMode("append")
words_stream_writer = words_stream_writer.trigger(processingTime="1 second")
words_stream_query = words_stream_writer.start()

try:
    words_stream_query.awaitTermination(10)
except Exception as e:
    print(f"Streaming failed: {str(e)}")
finally:
    words_stream_query.stop()
# Out:
# 25/05/13 00:57:42 WARN ResolveWriteToStream: Temporary checkpoint location created which is deleted normally when the query didn't fail: /tmp/temporary-82f7573c-48c6-497e-9936-1f7f4a70cf89. If it's required to delete it under any circumstances, please set spark.sql.streaming.forceDeleteTempCheckpointLocation to true. Important to know deleting temp checkpoint folder is best effort.
# 25/05/13 00:57:42 WARN ResolveWriteToStream: spark.sql.adaptive.enabled is not supported in streaming DataFrames/Datasets and will be disabled.
# -------------------------------------------
# Batch: 0
# -------------------------------------------
# +-----+
# |value|
# +-----+
# +-----+
#
# -------------------------------------------
# Batch: 1
# -------------------------------------------
# +--------------------+
# |               value|
# +--------------------+
# |12 fish sky orang...|
# +--------------------+
#
# -------------------------------------------
# Batch: 2
# -------------------------------------------
# +--------+
# |   value|
# +--------+
# |9 grape |
# +--------+
#
# -------------------------------------------
# Batch: 3
# -------------------------------------------
# +--------------------+
# |               value|
# +--------------------+
# |         17 avocado |
# |18 dog lemon elep...|
# +--------------------+
#
# -------------------------------------------
# Batch: 4
# -------------------------------------------
# +--------------------+
# |               value|
# +--------------------+
# |3 happy jelly dra...|
# +--------------------+
#
# -------------------------------------------
# Batch: 5
# -------------------------------------------
# +--------------------+
# |               value|
# +--------------------+
# |6 mermaid happy v...|
# |2 happy friend gr...|
# +--------------------+
#
# -------------------------------------------
# Batch: 6
# -------------------------------------------
# +-------+
# |  value|
# +-------+
# |2 lime |
# +-------+

# %% [markdown]
# ### Step 6: Transform the stream as requested `#TODO`
#
# 1. Each line of the stream starts with a number, let us call this number `user_id`. The rest of the line comprises a set of words generated by this user.
# 2. For each user request you must take the corresponding words, get the meaning of each word (static dataframe) and return the responses as a new stream of `user_id, [<meaning of word 1>, <meaning of word 2>, ... ]`
# 3. Let the stream running on console for 10 seconds.

# %%
from pyspark.sql.functions import split, col, explode, array, collect_list

processed_stream = words_stream \
    .select(
        split(col("value"), " ", 2).alias("data")
    ) \
    .select(
        col("data").getItem(0).alias("user_id"),
        split(col("data").getItem(1), " ").alias("words")
    ) \
    .withColumn("word", explode(col("words")))

enriched_stream = processed_stream \
    .join(words_with_meaning_df, "word", "left") \
    .groupBy("user_id") \
    .agg(collect_list("meaning").alias("meanings"))

query = enriched_stream \
    .writeStream \
    .outputMode("complete") \
    .format("console") \
    .trigger(processingTime="1 second") \
    .option("truncate", "false") \
    .start()

try:
    query.awaitTermination(10)
except Exception as e:
    print(f"Streaming failed: {str(e)}")
finally:
    query.stop()
# Out:
# 25/05/13 01:10:19 WARN ResolveWriteToStream: Temporary checkpoint location created which is deleted normally when the query didn't fail: /tmp/temporary-fb5a4447-7bf0-4857-bfe0-af57c41ed4f1. If it's required to delete it under any circumstances, please set spark.sql.streaming.forceDeleteTempCheckpointLocation to true. Important to know deleting temp checkpoint folder is best effort.
# 25/05/13 01:10:19 WARN ResolveWriteToStream: spark.sql.adaptive.enabled is not supported in streaming DataFrames/Datasets and will be disabled.
# -------------------------------------------
# Batch: 0
# -------------------------------------------
# +-------+--------+
# |user_id|meanings|
# +-------+--------+
# +-------+--------+
#
# -------------------------------------------
# Batch: 1
# -------------------------------------------
# +-------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |user_id|meanings                                                                                                                                                                                                                                                                                                                                                                                  |
# +-------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |13     |[An edible round berry, belonging to the cowberry group (Vaccinium sect. Cyanococcus), with flared crowns at the end, that turns blue on ripening., To move back and forth repeatedly and somewhat loosely., One who has won or often wins., A small evergreen tree native to Sri Lanka and southern India, Cinnamomum verum or Cinnamomum zeylanicum, belonging to the family Lauraceae.]|
# +-------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
#
# -------------------------------------------
# Batch: 2
# -------------------------------------------
# +-------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |user_id|meanings                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          |
# +-------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |15     |[A snack food made by combining graham crackers, marshmallows (frequently toasted) and chocolate, a typical camping fireside treat., A substance (of molecular formula H₂O) found at room temperature and pressure as a clear liquid; it is present naturally as rain, and found in rivers, lakes and seas; its solid form is ice and its gaseous form is steam., A large settlement, bigger than a town; sometimes with a specific legal definition, depending on the place., A collection of valuable things; accumulated wealth; a stock of money, jewels, etc., A species of mallow, Althaea officinalis, that grows in marshy terrain., A species of mallow, Althaea officinalis, that grows in marshy terrain.]             |
# |17     |[A shelf or shelves for storing books for easy visual reference., A two-handed, single-bladed oar used to propel a canoe or a small boat., The shore of a body of water, especially when sandy or pebbly., A sunfish., A rock; boulder; a hill., A fire at a campground or on a camping trip, often used for cooking, to provide light and heat, to drive away bugs, and as a focal point for sitting around in the evening and talking, telling stories, and singing., Any of very many animals (either hermaphroditic or nonhermaphroditic), of the class Gastropoda, having a coiled shell., To fill by packing or crowding something into; to cram with something; to load to excess., A hard external covering of an animal.]|
# |13     |[An edible round berry, belonging to the cowberry group (Vaccinium sect. Cyanococcus), with flared crowns at the end, that turns blue on ripening., To move back and forth repeatedly and somewhat loosely., One who has won or often wins., A small evergreen tree native to Sri Lanka and southern India, Cinnamomum verum or Cinnamomum zeylanicum, belonging to the family Lauraceae.]                                                                                                                                                                                                                                                                                                                                        |
# +-------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
#
# -------------------------------------------
# Batch: 3
# -------------------------------------------
# +-------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |user_id|meanings                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             |
# +-------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |15     |[A snack food made by combining graham crackers, marshmallows (frequently toasted) and chocolate, a typical camping fireside treat., A substance (of molecular formula H₂O) found at room temperature and pressure as a clear liquid; it is present naturally as rain, and found in rivers, lakes and seas; its solid form is ice and its gaseous form is steam., A large settlement, bigger than a town; sometimes with a specific legal definition, depending on the place., A collection of valuable things; accumulated wealth; a stock of money, jewels, etc., A species of mallow, Althaea officinalis, that grows in marshy terrain., A species of mallow, Althaea officinalis, that grows in marshy terrain.]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                |
# |8      |[The ruler of an absolute monarchy or the head of state of a constitutional monarchy., The sweet, usually red, edible fruit of certain plants of the genus Fragaria., To move back and forth repeatedly and somewhat loosely., One of the large bodies of water separating the continents., A rock; boulder; a hill., Any inorganic material containing calcium, usually calcium oxide (quicklime) or calcium hydroxide (slaked lime)., The atmosphere above a given point, especially as visible from the ground during the day., A herb of the mint family, Origanum vulgare, having aromatic leaves., An institution which holds books and/or other forms of media for use by the public or qualified people often lending them out, as well as providing various other services for its users., A common, round fruit produced by the tree Malus domestica, cultivated in temperate climates.]                                                                                                                                                                                                                                                                                                                                                                                                                   |
# |17     |[A shelf or shelves for storing books for easy visual reference., A two-handed, single-bladed oar used to propel a canoe or a small boat., The shore of a body of water, especially when sandy or pebbly., A sunfish., A rock; boulder; a hill., A fire at a campground or on a camping trip, often used for cooking, to provide light and heat, to drive away bugs, and as a focal point for sitting around in the evening and talking, telling stories, and singing., Any of very many animals (either hermaphroditic or nonhermaphroditic), of the class Gastropoda, having a coiled shell., To fill by packing or crowding something into; to cram with something; to load to excess., A hard external covering of an animal., A literary piece written in verse., A rock; boulder; a hill., A hard substance made of the limestone skeletons of marine polyps., A tropical plant, Ananas comosus, native to South America, having thirty or more long, spined and pointed leaves surrounding a thick stem., A cold-blooded vertebrate animal that lives in water, moving with the help of fins and breathing with gills., To live in a tent or similar temporary accommodation., Literary type using invented or imaginative writing, instead of real facts, usually written as prose., The plant Rubus idaeus.]|
# |13     |[An edible round berry, belonging to the cowberry group (Vaccinium sect. Cyanococcus), with flared crowns at the end, that turns blue on ripening., To move back and forth repeatedly and somewhat loosely., One who has won or often wins., A small evergreen tree native to Sri Lanka and southern India, Cinnamomum verum or Cinnamomum zeylanicum, belonging to the family Lauraceae.]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           |
# +-------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
#
# -------------------------------------------
# Batch: 4
# -------------------------------------------
# +-------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |user_id|meanings                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             |
# +-------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |15     |[A snack food made by combining graham crackers, marshmallows (frequently toasted) and chocolate, a typical camping fireside treat., A substance (of molecular formula H₂O) found at room temperature and pressure as a clear liquid; it is present naturally as rain, and found in rivers, lakes and seas; its solid form is ice and its gaseous form is steam., A large settlement, bigger than a town; sometimes with a specific legal definition, depending on the place., A collection of valuable things; accumulated wealth; a stock of money, jewels, etc., A species of mallow, Althaea officinalis, that grows in marshy terrain., A species of mallow, Althaea officinalis, that grows in marshy terrain.]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                |
# |8      |[The ruler of an absolute monarchy or the head of state of a constitutional monarchy., The sweet, usually red, edible fruit of certain plants of the genus Fragaria., To move back and forth repeatedly and somewhat loosely., One of the large bodies of water separating the continents., A rock; boulder; a hill., Any inorganic material containing calcium, usually calcium oxide (quicklime) or calcium hydroxide (slaked lime)., The atmosphere above a given point, especially as visible from the ground during the day., A herb of the mint family, Origanum vulgare, having aromatic leaves., An institution which holds books and/or other forms of media for use by the public or qualified people often lending them out, as well as providing various other services for its users., A common, round fruit produced by the tree Malus domestica, cultivated in temperate climates.]                                                                                                                                                                                                                                                                                                                                                                                                                   |
# |17     |[A shelf or shelves for storing books for easy visual reference., A two-handed, single-bladed oar used to propel a canoe or a small boat., The shore of a body of water, especially when sandy or pebbly., A sunfish., A rock; boulder; a hill., A fire at a campground or on a camping trip, often used for cooking, to provide light and heat, to drive away bugs, and as a focal point for sitting around in the evening and talking, telling stories, and singing., Any of very many animals (either hermaphroditic or nonhermaphroditic), of the class Gastropoda, having a coiled shell., To fill by packing or crowding something into; to cram with something; to load to excess., A hard external covering of an animal., A literary piece written in verse., A rock; boulder; a hill., A hard substance made of the limestone skeletons of marine polyps., A tropical plant, Ananas comosus, native to South America, having thirty or more long, spined and pointed leaves surrounding a thick stem., A cold-blooded vertebrate animal that lives in water, moving with the help of fins and breathing with gills., To live in a tent or similar temporary accommodation., Literary type using invented or imaginative writing, instead of real facts, usually written as prose., The plant Rubus idaeus.]|
# |12     |[An insect of the suborder Epiprocta or, more strictly, the infraorder Anisoptera, having four long transparent wings held perpendicular to a long body when perched., A dessert consisting of ice cream with various toppings., A pavilion or portable lodge consisting of skins, canvas, or some strong cloth, stretched and sustained by poles, used for sheltering people from the weather., Any plant of the labiate genus Thymus, such as the garden thyme, Thymus vulgaris, a warm, pungent aromatic, that is much used to give a relish to seasoning and soups., Something given to another voluntarily, without charge., To live in a tent or similar temporary accommodation., A beverage made by infusing the beans of the coffee plant in hot water., The guinea fowl (family Numididae).]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               |
# |13     |[An edible round berry, belonging to the cowberry group (Vaccinium sect. Cyanococcus), with flared crowns at the end, that turns blue on ripening., To move back and forth repeatedly and somewhat loosely., One who has won or often wins., A small evergreen tree native to Sri Lanka and southern India, Cinnamomum verum or Cinnamomum zeylanicum, belonging to the family Lauraceae.]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           |
# +-------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
#
# -------------------------------------------
# Batch: 5
# -------------------------------------------
# +-------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |user_id|meanings                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             |
# +-------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |15     |[A snack food made by combining graham crackers, marshmallows (frequently toasted) and chocolate, a typical camping fireside treat., A substance (of molecular formula H₂O) found at room temperature and pressure as a clear liquid; it is present naturally as rain, and found in rivers, lakes and seas; its solid form is ice and its gaseous form is steam., A large settlement, bigger than a town; sometimes with a specific legal definition, depending on the place., A collection of valuable things; accumulated wealth; a stock of money, jewels, etc., A species of mallow, Althaea officinalis, that grows in marshy terrain., A species of mallow, Althaea officinalis, that grows in marshy terrain.]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                |
# |8      |[The ruler of an absolute monarchy or the head of state of a constitutional monarchy., The sweet, usually red, edible fruit of certain plants of the genus Fragaria., To move back and forth repeatedly and somewhat loosely., One of the large bodies of water separating the continents., A rock; boulder; a hill., Any inorganic material containing calcium, usually calcium oxide (quicklime) or calcium hydroxide (slaked lime)., The atmosphere above a given point, especially as visible from the ground during the day., A herb of the mint family, Origanum vulgare, having aromatic leaves., An institution which holds books and/or other forms of media for use by the public or qualified people often lending them out, as well as providing various other services for its users., A common, round fruit produced by the tree Malus domestica, cultivated in temperate climates.]                                                                                                                                                                                                                                                                                                                                                                                                                   |
# |17     |[A shelf or shelves for storing books for easy visual reference., A two-handed, single-bladed oar used to propel a canoe or a small boat., The shore of a body of water, especially when sandy or pebbly., A sunfish., A rock; boulder; a hill., A fire at a campground or on a camping trip, often used for cooking, to provide light and heat, to drive away bugs, and as a focal point for sitting around in the evening and talking, telling stories, and singing., Any of very many animals (either hermaphroditic or nonhermaphroditic), of the class Gastropoda, having a coiled shell., To fill by packing or crowding something into; to cram with something; to load to excess., A hard external covering of an animal., A literary piece written in verse., A rock; boulder; a hill., A hard substance made of the limestone skeletons of marine polyps., A tropical plant, Ananas comosus, native to South America, having thirty or more long, spined and pointed leaves surrounding a thick stem., A cold-blooded vertebrate animal that lives in water, moving with the help of fins and breathing with gills., To live in a tent or similar temporary accommodation., Literary type using invented or imaginative writing, instead of real facts, usually written as prose., The plant Rubus idaeus.]|
# |12     |[An insect of the suborder Epiprocta or, more strictly, the infraorder Anisoptera, having four long transparent wings held perpendicular to a long body when perched., A dessert consisting of ice cream with various toppings., A pavilion or portable lodge consisting of skins, canvas, or some strong cloth, stretched and sustained by poles, used for sheltering people from the weather., Any plant of the labiate genus Thymus, such as the garden thyme, Thymus vulgaris, a warm, pungent aromatic, that is much used to give a relish to seasoning and soups., Something given to another voluntarily, without charge., To live in a tent or similar temporary accommodation., A beverage made by infusing the beans of the coffee plant in hot water., The guinea fowl (family Numididae).]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               |
# |13     |[An edible round berry, belonging to the cowberry group (Vaccinium sect. Cyanococcus), with flared crowns at the end, that turns blue on ripening., To move back and forth repeatedly and somewhat loosely., One who has won or often wins., A small evergreen tree native to Sri Lanka and southern India, Cinnamomum verum or Cinnamomum zeylanicum, belonging to the family Lauraceae., A mythological creature with a woman's head and upper body, and a tail of a fish., Any of various asteroids or other echinoderms (not in fact fish) with usually five arms, many of which eat bivalves or corals by everting their stomach.]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              |
# +-------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
#
# -------------------------------------------
# Batch: 6
# -------------------------------------------
# +-------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |user_id|meanings                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              |
# ...
# 	at org.apache.spark.sql.execution.streaming.StateStoreSaveExec.timeTakenMs(statefulOperators.scala:467)
# 	at org.apache.spark.sql.execution.streaming.StateStoreSaveExec.$anonfun$doExecute$5(statefulOperators.scala:511)
# 	at org.apache.spark.sql.execution.streaming.state.package$StateStoreOps.$anonfun$mapPartitionsWithStateStore$1(package.scala:68)
# 	at org.apache.spark.sql.execution.streaming.state.StateStoreRDD.compute(StateStoreRDD.scala:127)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:367)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:331)
# 	at org.apache.spark.rdd.MapPartitionsRDD.compute(MapPartitionsRDD.scala:52)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:367)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:331)
# 	at org.apache.spark.scheduler.ResultTask.runTask(ResultTask.scala:93)
# 	at org.apache.spark.TaskContext.runTaskWithListeners(TaskContext.scala:166)
# 	at org.apache.spark.scheduler.Task.run(Task.scala:141)
# 	at org.apache.spark.executor.Executor$TaskRunner.$anonfun$run$4(Executor.scala:620)
# 	at org.apache.spark.util.SparkErrorUtils.tryWithSafeFinally(SparkErrorUtils.scala:64)
# 	at org.apache.spark.util.SparkErrorUtils.tryWithSafeFinally$(SparkErrorUtils.scala:61)
# 	at org.apache.spark.util.Utils$.tryWithSafeFinally(Utils.scala:94)
# 	at org.apache.spark.executor.Executor$TaskRunner.run(Executor.scala:623)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628)
# 	at java.base/java.lang.Thread.run(Thread.java:829)
# 25/05/13 01:10:29 WARN Shell: Interrupted while joining on: Thread[Thread-102781,5,]
# java.lang.InterruptedException
# 	at java.base/java.lang.Object.wait(Native Method)
# 	at java.base/java.lang.Thread.join(Thread.java:1300)
# 	at java.base/java.lang.Thread.join(Thread.java:1375)
# 	at org.apache.hadoop.util.Shell.joinThread(Shell.java:1042)
# 	at org.apache.hadoop.util.Shell.runCommand(Shell.java:1002)
# 	at org.apache.hadoop.util.Shell.run(Shell.java:900)
# 	at org.apache.hadoop.util.Shell$ShellCommandExecutor.execute(Shell.java:1212)
# 	at org.apache.hadoop.util.Shell.execCommand(Shell.java:1306)
# 	at org.apache.hadoop.util.Shell.execCommand(Shell.java:1288)
# 	at org.apache.hadoop.fs.FileUtil.readLink(FileUtil.java:212)
# 	at org.apache.hadoop.fs.RawLocalFileSystem.deprecatedGetFileLinkStatusInternal(RawLocalFileSystem.java:1113)
# 	at org.apache.hadoop.fs.RawLocalFileSystem.getFileLinkStatusInternal(RawLocalFileSystem.java:1102)
# 	at org.apache.hadoop.fs.RawLocalFileSystem.getFileLinkStatus(RawLocalFileSystem.java:1073)
# 	at org.apache.hadoop.fs.DelegateToFileSystem.getFileLinkStatus(DelegateToFileSystem.java:133)
# 	at org.apache.hadoop.fs.AbstractFileSystem.renameInternal(AbstractFileSystem.java:751)
# 	at org.apache.hadoop.fs.AbstractFileSystem.rename(AbstractFileSystem.java:720)
# 	at org.apache.hadoop.fs.ChecksumFs.renameInternal(ChecksumFs.java:496)
# 	at org.apache.hadoop.fs.AbstractFileSystem.rename(AbstractFileSystem.java:720)
# 	at org.apache.hadoop.fs.FileContext.rename(FileContext.java:1036)
# 	at org.apache.spark.sql.execution.streaming.FileContextBasedCheckpointFileManager.renameTempFile(CheckpointFileManager.scala:372)
# 	at org.apache.spark.sql.execution.streaming.CheckpointFileManager$RenameBasedFSDataOutputStream.close(CheckpointFileManager.scala:154)
# 	at net.jpountz.lz4.LZ4BlockOutputStream.close(LZ4BlockOutputStream.java:198)
# 	at java.base/java.io.FilterOutputStream.close(FilterOutputStream.java:188)
# 	at org.apache.spark.sql.execution.streaming.state.HDFSBackedStateStoreProvider.finalizeDeltaFile(HDFSBackedStateStoreProvider.scala:453)
# 	at org.apache.spark.sql.execution.streaming.state.HDFSBackedStateStoreProvider.org$apache$spark$sql$execution$streaming$state$HDFSBackedStateStoreProvider$$commitUpdates(HDFSBackedStateStoreProvider.scala:323)
# 	at org.apache.spark.sql.execution.streaming.state.HDFSBackedStateStoreProvider$HDFSBackedStateStore.commit(HDFSBackedStateStoreProvider.scala:141)
# 	at org.apache.spark.sql.execution.streaming.state.StreamingAggregationStateManagerBaseImpl.commit(StreamingAggregationStateManager.scala:90)
# 	at org.apache.spark.sql.execution.streaming.StateStoreSaveExec.$anonfun$doExecute$7(statefulOperators.scala:511)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at org.apache.spark.util.Utils$.timeTakenMs(Utils.scala:552)
# 	at org.apache.spark.sql.execution.streaming.StateStoreWriter.timeTakenMs(statefulOperators.scala:179)
# 	at org.apache.spark.sql.execution.streaming.StateStoreWriter.timeTakenMs$(statefulOperators.scala:179)
# 	at org.apache.spark.sql.execution.streaming.StateStoreSaveExec.timeTakenMs(statefulOperators.scala:467)
# 	at org.apache.spark.sql.execution.streaming.StateStoreSaveExec.$anonfun$doExecute$5(statefulOperators.scala:511)
# 	at org.apache.spark.sql.execution.streaming.state.package$StateStoreOps.$anonfun$mapPartitionsWithStateStore$1(package.scala:68)
# 	at org.apache.spark.sql.execution.streaming.state.StateStoreRDD.compute(StateStoreRDD.scala:127)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:367)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:331)
# 	at org.apache.spark.rdd.MapPartitionsRDD.compute(MapPartitionsRDD.scala:52)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:367)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:331)
# 	at org.apache.spark.scheduler.ResultTask.runTask(ResultTask.scala:93)
# 	at org.apache.spark.TaskContext.runTaskWithListeners(TaskContext.scala:166)
# 	at org.apache.spark.scheduler.Task.run(Task.scala:141)
# 	at org.apache.spark.executor.Executor$TaskRunner.$anonfun$run$4(Executor.scala:620)
# 	at org.apache.spark.util.SparkErrorUtils.tryWithSafeFinally(SparkErrorUtils.scala:64)
# 	at org.apache.spark.util.SparkErrorUtils.tryWithSafeFinally$(SparkErrorUtils.scala:61)
# 	at org.apache.spark.util.Utils$.tryWithSafeFinally(Utils.scala:94)
# 	at org.apache.spark.executor.Executor$TaskRunner.run(Executor.scala:623)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628)
# 	at java.base/java.lang.Thread.run(Thread.java:829)
# 25/05/13 01:10:29 WARN Shell: Interrupted while joining on: Thread[Thread-102782,5,]
# java.lang.InterruptedException
# 	at java.base/java.lang.Object.wait(Native Method)
# 	at java.base/java.lang.Thread.join(Thread.java:1300)
# 	at java.base/java.lang.Thread.join(Thread.java:1375)
# 	at org.apache.hadoop.util.Shell.joinThread(Shell.java:1042)
# 	at org.apache.hadoop.util.Shell.runCommand(Shell.java:1002)
# 	at org.apache.hadoop.util.Shell.run(Shell.java:900)
# 	at org.apache.hadoop.util.Shell$ShellCommandExecutor.execute(Shell.java:1212)
# 	at org.apache.hadoop.util.Shell.execCommand(Shell.java:1306)
# 	at org.apache.hadoop.util.Shell.execCommand(Shell.java:1288)
# 	at org.apache.hadoop.fs.FileUtil.readLink(FileUtil.java:212)
# 	at org.apache.hadoop.fs.RawLocalFileSystem.deprecatedGetFileLinkStatusInternal(RawLocalFileSystem.java:1113)
# 	at org.apache.hadoop.fs.RawLocalFileSystem.getFileLinkStatusInternal(RawLocalFileSystem.java:1102)
# 	at org.apache.hadoop.fs.RawLocalFileSystem.getFileLinkStatus(RawLocalFileSystem.java:1073)
# 	at org.apache.hadoop.fs.DelegateToFileSystem.getFileLinkStatus(DelegateToFileSystem.java:133)
# 	at org.apache.hadoop.fs.AbstractFileSystem.renameInternal(AbstractFileSystem.java:747)
# 	at org.apache.hadoop.fs.AbstractFileSystem.rename(AbstractFileSystem.java:720)
# 	at org.apache.hadoop.fs.ChecksumFs.renameInternal(ChecksumFs.java:496)
# 	at org.apache.hadoop.fs.AbstractFileSystem.rename(AbstractFileSystem.java:720)
# 	at org.apache.hadoop.fs.FileContext.rename(FileContext.java:1036)
# 	at org.apache.spark.sql.execution.streaming.FileContextBasedCheckpointFileManager.renameTempFile(CheckpointFileManager.scala:372)
# 	at org.apache.spark.sql.execution.streaming.CheckpointFileManager$RenameBasedFSDataOutputStream.close(CheckpointFileManager.scala:154)
# 	at net.jpountz.lz4.LZ4BlockOutputStream.close(LZ4BlockOutputStream.java:198)
# 	at java.base/java.io.FilterOutputStream.close(FilterOutputStream.java:188)
# 	at org.apache.spark.sql.execution.streaming.state.HDFSBackedStateStoreProvider.finalizeDeltaFile(HDFSBackedStateStoreProvider.scala:453)
# 	at org.apache.spark.sql.execution.streaming.state.HDFSBackedStateStoreProvider.org$apache$spark$sql$execution$streaming$state$HDFSBackedStateStoreProvider$$commitUpdates(HDFSBackedStateStoreProvider.scala:323)
# 	at org.apache.spark.sql.execution.streaming.state.HDFSBackedStateStoreProvider$HDFSBackedStateStore.commit(HDFSBackedStateStoreProvider.scala:141)
# 	at org.apache.spark.sql.execution.streaming.state.StreamingAggregationStateManagerBaseImpl.commit(StreamingAggregationStateManager.scala:90)
# 	at org.apache.spark.sql.execution.streaming.StateStoreSaveExec.$anonfun$doExecute$7(statefulOperators.scala:511)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at org.apache.spark.util.Utils$.timeTakenMs(Utils.scala:552)
# 	at org.apache.spark.sql.execution.streaming.StateStoreWriter.timeTakenMs(statefulOperators.scala:179)
# 	at org.apache.spark.sql.execution.streaming.StateStoreWriter.timeTakenMs$(statefulOperators.scala:179)
# 	at org.apache.spark.sql.execution.streaming.StateStoreSaveExec.timeTakenMs(statefulOperators.scala:467)
# 	at org.apache.spark.sql.execution.streaming.StateStoreSaveExec.$anonfun$doExecute$5(statefulOperators.scala:511)
# 	at org.apache.spark.sql.execution.streaming.state.package$StateStoreOps.$anonfun$mapPartitionsWithStateStore$1(package.scala:68)
# 	at org.apache.spark.sql.execution.streaming.state.StateStoreRDD.compute(StateStoreRDD.scala:127)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:367)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:331)
# 	at org.apache.spark.rdd.MapPartitionsRDD.compute(MapPartitionsRDD.scala:52)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:367)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:331)
# 	at org.apache.spark.scheduler.ResultTask.runTask(ResultTask.scala:93)
# 	at org.apache.spark.TaskContext.runTaskWithListeners(TaskContext.scala:166)
# 	at org.apache.spark.scheduler.Task.run(Task.scala:141)
# 	at org.apache.spark.executor.Executor$TaskRunner.$anonfun$run$4(Executor.scala:620)
# 	at org.apache.spark.util.SparkErrorUtils.tryWithSafeFinally(SparkErrorUtils.scala:64)
# 	at org.apache.spark.util.SparkErrorUtils.tryWithSafeFinally$(SparkErrorUtils.scala:61)
# 	at org.apache.spark.util.Utils$.tryWithSafeFinally(Utils.scala:94)
# 	at org.apache.spark.executor.Executor$TaskRunner.run(Executor.scala:623)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628)
# 	at java.base/java.lang.Thread.run(Thread.java:829)
# 25/05/13 01:10:29 WARN TaskSetManager: Lost task 25.0 in stage 191.0 (TID 13043) (acaa0d420fb5 executor driver): TaskKilled (Stage cancelled: Job 140 cancelled part of cancelled job group 1ea23b68-5f4b-469d-8b01-af00b25b7a60)
# 25/05/13 01:10:29 WARN TaskSetManager: Lost task 34.0 in stage 191.0 (TID 13052) (acaa0d420fb5 executor driver): TaskKilled (Stage cancelled: Job 140 cancelled part of cancelled job group 1ea23b68-5f4b-469d-8b01-af00b25b7a60)
# 25/05/13 01:10:29 WARN TaskSetManager: Lost task 38.0 in stage 191.0 (TID 13056) (acaa0d420fb5 executor driver): TaskKilled (Stage cancelled: Job 140 cancelled part of cancelled job group 1ea23b68-5f4b-469d-8b01-af00b25b7a60)
# 25/05/13 01:10:29 WARN TaskSetManager: Lost task 32.0 in stage 191.0 (TID 13050) (acaa0d420fb5 executor driver): TaskKilled (Stage cancelled: Job 140 cancelled part of cancelled job group 1ea23b68-5f4b-469d-8b01-af00b25b7a60)
# 25/05/13 01:10:29 WARN TaskSetManager: Lost task 30.0 in stage 191.0 (TID 13048) (acaa0d420fb5 executor driver): TaskKilled (Stage cancelled: Job 140 cancelled part of cancelled job group 1ea23b68-5f4b-469d-8b01-af00b25b7a60)
# 25/05/13 01:10:29 WARN TaskSetManager: Lost task 31.0 in stage 191.0 (TID 13049) (acaa0d420fb5 executor driver): TaskKilled (Stage cancelled: Job 140 cancelled part of cancelled job group 1ea23b68-5f4b-469d-8b01-af00b25b7a60)
# 25/05/13 01:10:29 WARN TaskSetManager: Lost task 33.0 in stage 191.0 (TID 13051) (acaa0d420fb5 executor driver): TaskKilled (Stage cancelled: Job 140 cancelled part of cancelled job group 1ea23b68-5f4b-469d-8b01-af00b25b7a60)
# 25/05/13 01:10:29 WARN TaskSetManager: Lost task 28.0 in stage 191.0 (TID 13046) (acaa0d420fb5 executor driver): TaskKilled (Stage cancelled: Job 140 cancelled part of cancelled job group 1ea23b68-5f4b-469d-8b01-af00b25b7a60)
# 25/05/13 01:10:29 WARN TaskSetManager: Lost task 47.0 in stage 191.0 (TID 13065) (acaa0d420fb5 executor driver): TaskKilled (Stage cancelled: Job 140 cancelled part of cancelled job group 1ea23b68-5f4b-469d-8b01-af00b25b7a60)
# 25/05/13 01:10:29 WARN TaskSetManager: Lost task 43.0 in stage 191.0 (TID 13061) (acaa0d420fb5 executor driver): TaskKilled (Stage cancelled: Job 140 cancelled part of cancelled job group 1ea23b68-5f4b-469d-8b01-af00b25b7a60)
# 25/05/13 01:10:29 WARN TaskSetManager: Lost task 44.0 in stage 191.0 (TID 13062) (acaa0d420fb5 executor driver): TaskKilled (Stage cancelled: Job 140 cancelled part of cancelled job group 1ea23b68-5f4b-469d-8b01-af00b25b7a60)
# 25/05/13 01:10:29 WARN TaskSetManager: Lost task 45.0 in stage 191.0 (TID 13063) (acaa0d420fb5 executor driver): TaskKilled (Stage cancelled: Job 140 cancelled part of cancelled job group 1ea23b68-5f4b-469d-8b01-af00b25b7a60)
# 25/05/13 01:10:29 WARN TaskSetManager: Lost task 29.0 in stage 191.0 (TID 13047) (acaa0d420fb5 executor driver): TaskKilled (Stage cancelled: Job 140 cancelled part of cancelled job group 1ea23b68-5f4b-469d-8b01-af00b25b7a60)
# 25/05/13 01:10:29 WARN FileUtil: Failed to delete file or dir [/tmp/temporary-fb5a4447-7bf0-4857-bfe0-af57c41ed4f1/state/0/42]: it still exists.
# 25/05/13 01:10:29 WARN TaskSetManager: Lost task 42.0 in stage 191.0 (TID 13060) (acaa0d420fb5 executor driver): TaskKilled (Stage cancelled: Job 140 cancelled part of cancelled job group 1ea23b68-5f4b-469d-8b01-af00b25b7a60)
# 25/05/13 01:10:29 WARN TaskSetManager: Lost task 26.0 in stage 191.0 (TID 13044) (acaa0d420fb5 executor driver): TaskKilled (Stage cancelled: Job 140 cancelled part of cancelled job group 1ea23b68-5f4b-469d-8b01-af00b25b7a60)
# 25/05/13 01:10:29 WARN TaskSetManager: Lost task 40.0 in stage 191.0 (TID 13058) (acaa0d420fb5 executor driver): TaskKilled (Stage cancelled: Job 140 cancelled part of cancelled job group 1ea23b68-5f4b-469d-8b01-af00b25b7a60)
# 25/05/13 01:10:29 WARN TaskSetManager: Lost task 35.0 in stage 191.0 (TID 13053) (acaa0d420fb5 executor driver): TaskKilled (Stage cancelled: Job 140 cancelled part of cancelled job group 1ea23b68-5f4b-469d-8b01-af00b25b7a60)
# 25/05/13 01:10:29 WARN TaskSetManager: Lost task 37.0 in stage 191.0 (TID 13055) (acaa0d420fb5 executor driver): TaskKilled (Stage cancelled: Job 140 cancelled part of cancelled job group 1ea23b68-5f4b-469d-8b01-af00b25b7a60)
# 25/05/13 01:10:29 WARN TaskSetManager: Lost task 39.0 in stage 191.0 (TID 13057) (acaa0d420fb5 executor driver): TaskKilled (Stage cancelled: Job 140 cancelled part of cancelled job group 1ea23b68-5f4b-469d-8b01-af00b25b7a60)
# 25/05/13 01:10:29 WARN TaskSetManager: Lost task 41.0 in stage 191.0 (TID 13059) (acaa0d420fb5 executor driver): TaskKilled (Stage cancelled: Job 140 cancelled part of cancelled job group 1ea23b68-5f4b-469d-8b01-af00b25b7a60)
# 25/05/13 01:10:29 WARN TaskSetManager: Lost task 27.0 in stage 191.0 (TID 13045) (acaa0d420fb5 executor driver): TaskKilled (Stage cancelled: Job 140 cancelled part of cancelled job group 1ea23b68-5f4b-469d-8b01-af00b25b7a60)
# 25/05/13 01:10:29 WARN TaskSetManager: Lost task 46.0 in stage 191.0 (TID 13064) (acaa0d420fb5 executor driver): TaskKilled (Stage cancelled: Job 140 cancelled part of cancelled job group 1ea23b68-5f4b-469d-8b01-af00b25b7a60)

# %% [markdown]
# ### Step 7: Transform the stream as requested `#TODO`
#
# 1. Again, from the stream of lines `words_stream`
# 2. Map each line to rows of `word,user_id` (hint: use `explode` and `split`)
# 3. From this new stream, group by word and aggregate the set of user IDs that asked for that specific word.
# 4. Generate a stream of `<list of user IDs> <word> <meaning of word>`
# 5. Let the resulting stream running for 20 seconds.

# %%
from pyspark.sql.functions import split, col, explode, collect_set, array_join

word_user_stream = words_stream \
    .select(
        split(col("value"), " ", 2).alias("data")
    ) \
    .select(
        col("data").getItem(0).alias("user_id"),
        split(col("data").getItem(1), " ").alias("words")
    ) \
    .select(
        col("user_id"),
        explode(col("words")).alias("word")
    )

result_stream = word_user_stream \
    .join(words_with_meaning_df, "word", "left") \
    .groupBy("word", "meaning") \
    .agg(
        collect_set("user_id").alias("user_ids"),
        count("*").alias("request_count")
    ) \
    .select(
        array_join(col("user_ids"), ",").alias("user_ids"),
        col("word"),
        col("meaning"),
        col("request_count")
    )

query = result_stream \
    .writeStream \
    .outputMode("complete") \
    .format("console") \
    .option("truncate", False) \
    .option("numRows", 20) \
    .option("checkpointLocation", "file:///tmp/word_user_checkpoint") \
    .trigger(processingTime="1 second") \
    .start()

try:
    query.awaitTermination(20)
except KeyboardInterrupt:
    pass
finally:
    query.stop()
# Out:
# 25/05/13 01:08:51 WARN ResolveWriteToStream: spark.sql.adaptive.enabled is not supported in streaming DataFrames/Datasets and will be disabled.
# -------------------------------------------
# Batch: 0
# -------------------------------------------
# +--------+----+-------+-------------+
# |user_ids|word|meaning|request_count|
# +--------+----+-------+-------------+
# +--------+----+-------+-------------+
#
# -------------------------------------------
# Batch: 1
# -------------------------------------------
# +--------+---------+-------------------------------------------------------------------------------------------------------------------------------------------------------------+-------------+
# |user_ids|word     |meaning                                                                                                                                                      |request_count|
# +--------+---------+-------------------------------------------------------------------------------------------------------------------------------------------------------------+-------------+
# |7       |brownie  |A small square piece of rich cake, usually made with chocolate.                                                                                              |1            |
# |7       |winner   |One who has won or often wins.                                                                                                                               |1            |
# |7       |rosemary |A shrub, Rosmarinus officinalis, that originates from Europe and Asia Minor and produces a fragrant herb used in cooking and perfumes.                       |1            |
# |7       |butterfly|A flying insect of the order Lepidoptera, distinguished from moths by their diurnal activity and generally brighter colouring.                               |1            |
# |7       |nutmeg   |An evergreen tree (Myristica fragrans) cultivated in the East Indies for its spicy seeds.                                                                    |1            |
# |7       |cycling  |To ride a bicycle or other cycle.                                                                                                                            |1            |
# |7       |raspberry|The plant Rubus idaeus.                                                                                                                                      |1            |
# |7       |peanut   |NULL                                                                                                                                                         |1            |
# |7       |butter   |NULL                                                                                                                                                         |1            |
# |7       |phone    |A device for transmitting conversations and other sounds in real time across distances, now often a small portable unit also capable of running software etc.|1            |
# |7       |         |NULL                                                                                                                                                         |1            |
# |7       |reef     |A chain or range of rocks, sand, or coral lying at or near the surface of the water.                                                                         |1            |
# +--------+---------+-------------------------------------------------------------------------------------------------------------------------------------------------------------+-------------+
#
# -------------------------------------------
# Batch: 2
# -------------------------------------------
# +--------+-----------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------------+
# |user_ids|word       |meaning                                                                                                                                                                                  |request_count|
# +--------+-----------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------------+
# |7       |brownie    |A small square piece of rich cake, usually made with chocolate.                                                                                                                          |1            |
# |1,14    |speed      |The state of moving quickly or the capacity for rapid motion; rapidity.                                                                                                                  |2            |
# |1       |vacation   |Freedom from some business or activity.                                                                                                                                                  |1            |
# |14      |computer   |A person employed to perform computations; one who computes.                                                                                                                             |1            |
# |1       |racing     |To take part in a race (in the sense of a contest).                                                                                                                                      |1            |
# |14      |dog        |A mammal, Canis familiaris or Canis lupus familiaris, that has been domesticated for thousands of years, of highly variable appearance due to human breeding.                            |1            |
# |1       |stuffing   |To fill by packing or crowding something into; to cram with something; to load to excess.                                                                                                |1            |
# |14      |swimming   |The act or art of sustaining and propelling the body in water.                                                                                                                           |1            |
# |7       |winner     |One who has won or often wins.                                                                                                                                                           |1            |
# |7       |rosemary   |A shrub, Rosmarinus officinalis, that originates from Europe and Asia Minor and produces a fragrant herb used in cooking and perfumes.                                                   |1            |
# |7       |butterfly  |A flying insect of the order Lepidoptera, distinguished from moths by their diurnal activity and generally brighter colouring.                                                           |1            |
# |14,7    |nutmeg     |An evergreen tree (Myristica fragrans) cultivated in the East Indies for its spicy seeds.                                                                                                |2            |
# |1       |library    |An institution which holds books and/or other forms of media for use by the public or qualified people often lending them out, as well as providing various other services for its users.|1            |
# |14      |mint       |A building or institution where money (originally, only coins) is produced under government licence.                                                                                     |1            |
# |7       |cycling    |To ride a bicycle or other cycle.                                                                                                                                                        |1            |
# |14      |starfish   |Any of various asteroids or other echinoderms (not in fact fish) with usually five arms, many of which eat bivalves or corals by everting their stomach.                                 |1            |
# |1       |marshmallow|A species of mallow, Althaea officinalis, that grows in marshy terrain.                                                                                                                  |4            |
# |1       |cookie     |A small, flat, baked good which is either crisp or soft but firm.                                                                                                                        |1            |
# |1       |grape      |A small, round, smooth-skinned edible fruit, usually purple, red, or green, that grows in bunches on vines of genus Vitis.                                                               |1            |
# |7       |raspberry  |The plant Rubus idaeus.                                                                                                                                                                  |1            |
# +--------+-----------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------------+
# only showing top 20 rows
#
# -------------------------------------------
# Batch: 3
# -------------------------------------------
# +--------+---------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------------+
# |user_ids|word     |meaning                                                                                                                                                                                                                                 |request_count|
# +--------+---------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------------+
# |7       |brownie  |A small square piece of rich cake, usually made with chocolate.                                                                                                                                                                         |1            |
# |1,14    |speed    |The state of moving quickly or the capacity for rapid motion; rapidity.                                                                                                                                                                 |2            |
# |1       |vacation |Freedom from some business or activity.                                                                                                                                                                                                 |1            |
# |12,14   |computer |A person employed to perform computations; one who computes.                                                                                                                                                                            |2            |
# |12      |jelly    |An explosive mixture of nitroglycerine and nitrate absorbed onto a base of wood pulp.                                                                                                                                                   |1            |
# |1       |racing   |To take part in a race (in the sense of a contest).                                                                                                                                                                                     |1            |
# |12,14   |dog      |A mammal, Canis familiaris or Canis lupus familiaris, that has been domesticated for thousands of years, of highly variable appearance due to human breeding.                                                                           |2            |
# |1       |stuffing |To fill by packing or crowding something into; to cram with something; to load to excess.                                                                                                                                               |1            |
# |14      |swimming |The act or art of sustaining and propelling the body in water.                                                                                                                                                                          |1            |
# |7       |winner   |One who has won or often wins.                                                                                                                                                                                                          |1            |
# |12      |snail    |Any of very many animals (either hermaphroditic or nonhermaphroditic), of the class Gastropoda, having a coiled shell.                                                                                                                  |1            |
# |7       |rosemary |A shrub, Rosmarinus officinalis, that originates from Europe and Asia Minor and produces a fragrant herb used in cooking and perfumes.                                                                                                  |1            |
# |12,7    |butterfly|A flying insect of the order Lepidoptera, distinguished from moths by their diurnal activity and generally brighter colouring.                                                                                                          |2            |
# |12      |firework |A device using gunpowder and other chemicals which, when lit, emits a combination of coloured flames, sparks, whistles or bangs, and sometimes made to rocket high into the sky before exploding, used for entertainment or celebration.|1            |
# |14,7    |nutmeg   |An evergreen tree (Myristica fragrans) cultivated in the East Indies for its spicy seeds.                                                                                                                                               |2            |
# |1       |library  |An institution which holds books and/or other forms of media for use by the public or qualified people often lending them out, as well as providing various other services for its users.                                               |1            |
# |14      |mint     |A building or institution where money (originally, only coins) is produced under government licence.                                                                                                                                    |1            |
# |12      |bookshelf|A shelf or shelves for storing books for easy visual reference.                                                                                                                                                                         |1            |
# |7       |cycling  |To ride a bicycle or other cycle.                                                                                                                                                                                                       |1            |
# |12      |monarch  |The ruler of an absolute monarchy or the head of state of a constitutional monarchy.                                                                                                                                                    |1            |
# +--------+---------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------------+
# only showing top 20 rows
#
# -------------------------------------------
# Batch: 4
# -------------------------------------------
# +--------+---------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------------+
# |user_ids|word     |meaning                                                                                                                                                                                                                                 |request_count|
# +--------+---------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------------+
# |7       |brownie  |A small square piece of rich cake, usually made with chocolate.                                                                                                                                                                         |1            |
# |1,14    |speed    |The state of moving quickly or the capacity for rapid motion; rapidity.                                                                                                                                                                 |2            |
# |1,6     |vacation |Freedom from some business or activity.                                                                                                                                                                                                 |2            |
# |12,14   |computer |A person employed to perform computations; one who computes.                                                                                                                                                                            |2            |
# |12      |jelly    |An explosive mixture of nitroglycerine and nitrate absorbed onto a base of wood pulp.                                                                                                                                                   |1            |
# |1,15    |racing   |To take part in a race (in the sense of a contest).                                                                                                                                                                                     |2            |
# |15      |poem     |A literary piece written in verse.                                                                                                                                                                                                      |1            |
# |12,14   |dog      |A mammal, Canis familiaris or Canis lupus familiaris, that has been domesticated for thousands of years, of highly variable appearance due to human breeding.                                                                           |2            |
# |1       |stuffing |To fill by packing or crowding something into; to cram with something; to load to excess.                                                                                                                                               |1            |
# |15      |mermaid  |A mythological creature with a woman's head and upper body, and a tail of a fish.                                                                                                                                                       |1            |
# |14      |swimming |The act or art of sustaining and propelling the body in water.                                                                                                                                                                          |1            |
# |15,7    |winner   |One who has won or often wins.                                                                                                                                                                                                          |2            |
# |12      |snail    |Any of very many animals (either hermaphroditic or nonhermaphroditic), of the class Gastropoda, having a coiled shell.                                                                                                                  |1            |
# |7       |rosemary |A shrub, Rosmarinus officinalis, that originates from Europe and Asia Minor and produces a fragrant herb used in cooking and perfumes.                                                                                                  |1            |
# |12,7    |butterfly|A flying insect of the order Lepidoptera, distinguished from moths by their diurnal activity and generally brighter colouring.                                                                                                          |2            |
# |12,15   |firework |A device using gunpowder and other chemicals which, when lit, emits a combination of coloured flames, sparks, whistles or bangs, and sometimes made to rocket high into the sky before exploding, used for entertainment or celebration.|2            |
# |14,7    |nutmeg   |An evergreen tree (Myristica fragrans) cultivated in the East Indies for its spicy seeds.                                                                                                                                               |2            |
# |1       |library  |An institution which holds books and/or other forms of media for use by the public or qualified people often lending them out, as well as providing various other services for its users.                                               |1            |
# |6       |mountain |An elevation of land of considerable dimensions rising more or less abruptly, forming a conspicuous figure in the landscape, usually having a small extent of surface at its summit.                                                    |1            |
# |6       |sundae   |A dessert consisting of ice cream with various toppings.                                                                                                                                                                                |1            |
# +--------+---------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------------+
# only showing top 20 rows
#
# -------------------------------------------
# Batch: 5
# -------------------------------------------
# +--------+---------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------------+
# |user_ids|word     |meaning                                                                                                                                                                                                                                 |request_count|
# +--------+---------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------------+
# |7       |brownie  |A small square piece of rich cake, usually made with chocolate.                                                                                                                                                                         |1            |
# |1,14    |speed    |The state of moving quickly or the capacity for rapid motion; rapidity.                                                                                                                                                                 |2            |
# |1,6     |vacation |Freedom from some business or activity.                                                                                                                                                                                                 |2            |
# |12,14   |computer |A person employed to perform computations; one who computes.                                                                                                                                                                            |2            |
# |12      |jelly    |An explosive mixture of nitroglycerine and nitrate absorbed onto a base of wood pulp.                                                                                                                                                   |1            |
# |1,15    |racing   |To take part in a race (in the sense of a contest).                                                                                                                                                                                     |2            |
# |15      |poem     |A literary piece written in verse.                                                                                                                                                                                                      |1            |
# |12,14   |dog      |A mammal, Canis familiaris or Canis lupus familiaris, that has been domesticated for thousands of years, of highly variable appearance due to human breeding.                                                                           |2            |
# |1       |stuffing |To fill by packing or crowding something into; to cram with something; to load to excess.                                                                                                                                               |1            |
# |15      |mermaid  |A mythological creature with a woman's head and upper body, and a tail of a fish.                                                                                                                                                       |1            |
# |14      |swimming |The act or art of sustaining and propelling the body in water.                                                                                                                                                                          |1            |
# |15,7    |winner   |One who has won or often wins.                                                                                                                                                                                                          |2            |
# |12      |snail    |Any of very many animals (either hermaphroditic or nonhermaphroditic), of the class Gastropoda, having a coiled shell.                                                                                                                  |1            |
# |7       |rosemary |A shrub, Rosmarinus officinalis, that originates from Europe and Asia Minor and produces a fragrant herb used in cooking and perfumes.                                                                                                  |1            |
# |12,7    |butterfly|A flying insect of the order Lepidoptera, distinguished from moths by their diurnal activity and generally brighter colouring.                                                                                                          |2            |
# |12,15   |firework |A device using gunpowder and other chemicals which, when lit, emits a combination of coloured flames, sparks, whistles or bangs, and sometimes made to rocket high into the sky before exploding, used for entertainment or celebration.|2            |
# |14,7    |nutmeg   |An evergreen tree (Myristica fragrans) cultivated in the East Indies for its spicy seeds.                                                                                                                                               |2            |
# |1,14    |library  |An institution which holds books and/or other forms of media for use by the public or qualified people often lending them out, as well as providing various other services for its users.                                               |2            |
# |6       |mountain |An elevation of land of considerable dimensions rising more or less abruptly, forming a conspicuous figure in the landscape, usually having a small extent of surface at its summit.                                                    |1            |
# |6       |sundae   |A dessert consisting of ice cream with various toppings.                                                                                                                                                                                |1            |
# +--------+---------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------------+
# only showing top 20 rows
#
# -------------------------------------------
# Batch: 6
# -------------------------------------------
# +--------+---------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------------+
# |user_ids|word     |meaning                                                                                                                                                                                                                                 |request_count|
# +--------+---------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------------+
# |7       |brownie  |A small square piece of rich cake, usually made with chocolate.                                                                                                                                                                         |1            |
# |3,1,14  |speed    |The state of moving quickly or the capacity for rapid motion; rapidity.                                                                                                                                                                 |3            |
# |3       |elephant |A mammal of the order Proboscidea, having a trunk, and two large ivory tusks jutting from the upper jaw.                                                                                                                                |1            |
# |1,6     |vacation |Freedom from some business or activity.                                                                                                                                                                                                 |2            |
# |3,12,14 |computer |A person employed to perform computations; one who computes.                                                                                                                                                                            |3            |
# |12      |jelly    |An explosive mixture of nitroglycerine and nitrate absorbed onto a base of wood pulp.                                                                                                                                                   |1            |
# |1,15    |racing   |To take part in a race (in the sense of a contest).                                                                                                                                                                                     |2            |
# |15      |poem     |A literary piece written in verse.                                                                                                                                                                                                      |1            |
# |12,14   |dog      |A mammal, Canis familiaris or Canis lupus familiaris, that has been domesticated for thousands of years, of highly variable appearance due to human breeding.                                                                           |2            |
# |1       |stuffing |To fill by packing or crowding something into; to cram with something; to load to excess.                                                                                                                                               |1            |
# |15      |mermaid  |A mythological creature with a woman's head and upper body, and a tail of a fish.                                                                                                                                                       |1            |
# |14      |swimming |The act or art of sustaining and propelling the body in water.                                                                                                                                                                          |1            |
# |15,7    |winner   |One who has won or often wins.                                                                                                                                                                                                          |2            |
# |12      |snail    |Any of very many animals (either hermaphroditic or nonhermaphroditic), of the class Gastropoda, having a coiled shell.                                                                                                                  |1            |
# |7       |rosemary |A shrub, Rosmarinus officinalis, that originates from Europe and Asia Minor and produces a fragrant herb used in cooking and perfumes.                                                                                                  |1            |
# |12,7    |butterfly|A flying insect of the order Lepidoptera, distinguished from moths by their diurnal activity and generally brighter colouring.                                                                                                          |2            |
# |12,15   |firework |A device using gunpowder and other chemicals which, when lit, emits a combination of coloured flames, sparks, whistles or bangs, and sometimes made to rocket high into the sky before exploding, used for entertainment or celebration.|2            |
# |14,7    |nutmeg   |An evergreen tree (Myristica fragrans) cultivated in the East Indies for its spicy seeds.                                                                                                                                               |2            |
# |1,14    |library  |An institution which holds books and/or other forms of media for use by the public or qualified people often lending them out, as well as providing various other services for its users.                                               |2            |
# |6       |mountain |An elevation of land of considerable dimensions rising more or less abruptly, forming a conspicuous figure in the landscape, usually having a small extent of surface at its summit.                                                    |1            |
# +--------+---------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------------+
# only showing top 20 rows
#
# -------------------------------------------
# Batch: 7
# -------------------------------------------
# +--------+---------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------------+
# |user_ids|word     |meaning                                                                                                                                                                                                                                 |request_count|
# +--------+---------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------------+
# |7       |brownie  |A small square piece of rich cake, usually made with chocolate.                                                                                                                                                                         |1            |
# |3,1,14  |speed    |The state of moving quickly or the capacity for rapid motion; rapidity.                                                                                                                                                                 |3            |
# |3       |elephant |A mammal of the order Proboscidea, having a trunk, and two large ivory tusks jutting from the upper jaw.                                                                                                                                |1            |
# |1,6     |vacation |Freedom from some business or activity.                                                                                                                                                                                                 |2            |
# |3,12,14 |computer |A person employed to perform computations; one who computes.                                                                                                                                                                            |3            |
# |12      |jelly    |An explosive mixture of nitroglycerine and nitrate absorbed onto a base of wood pulp.                                                                                                                                                   |1            |
# |5       |hot      |NULL                                                                                                                                                                                                                                    |1            |
# |1,15    |racing   |To take part in a race (in the sense of a contest).                                                                                                                                                                                     |2            |
# |15      |poem     |A literary piece written in verse.                                                                                                                                                                                                      |1            |
# |12,14   |dog      |A mammal, Canis familiaris or Canis lupus familiaris, that has been domesticated for thousands of years, of highly variable appearance due to human breeding.                                                                           |2            |
# |1       |stuffing |To fill by packing or crowding something into; to cram with something; to load to excess.                                                                                                                                               |1            |
# |15      |mermaid  |A mythological creature with a woman's head and upper body, and a tail of a fish.                                                                                                                                                       |1            |
# |14      |swimming |The act or art of sustaining and propelling the body in water.                                                                                                                                                                          |1            |
# |15,7    |winner   |One who has won or often wins.                                                                                                                                                                                                          |2            |
# |12      |snail    |Any of very many animals (either hermaphroditic or nonhermaphroditic), of the class Gastropoda, having a coiled shell.                                                                                                                  |1            |
# |7       |rosemary |A shrub, Rosmarinus officinalis, that originates from Europe and Asia Minor and produces a fragrant herb used in cooking and perfumes.                                                                                                  |1            |
# |12,7    |butterfly|A flying insect of the order Lepidoptera, distinguished from moths by their diurnal activity and generally brighter colouring.                                                                                                          |2            |
# |12,15   |firework |A device using gunpowder and other chemicals which, when lit, emits a combination of coloured flames, sparks, whistles or bangs, and sometimes made to rocket high into the sky before exploding, used for entertainment or celebration.|2            |
# |5,14,7  |nutmeg   |An evergreen tree (Myristica fragrans) cultivated in the East Indies for its spicy seeds.                                                                                                                                               |3            |
# |1,14    |library  |An institution which holds books and/or other forms of media for use by the public or qualified people often lending them out, as well as providing various other services for its users.                                               |2            |
# +--------+---------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------------+
# only showing top 20 rows
#
# -------------------------------------------
# Batch: 8
# -------------------------------------------
# +--------+---------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------------+
# |user_ids|word     |meaning                                                                                                                                                                                                                    |request_count|
# +--------+---------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------------+
# |7       |brownie  |A small square piece of rich cake, usually made with chocolate.                                                                                                                                                            |1            |
# |3,1,14  |speed    |The state of moving quickly or the capacity for rapid motion; rapidity.                                                                                                                                                    |3            |
# |5       |coffee   |A beverage made by infusing the beans of the coffee plant in hot water.                                                                                                                                                    |1            |
# |3       |elephant |A mammal of the order Proboscidea, having a trunk, and two large ivory tusks jutting from the upper jaw.                                                                                                                   |1            |
# |1,6     |vacation |Freedom from some business or activity.                                                                                                                                                                                    |2            |
# |3,12,14 |computer |A person employed to perform computations; one who computes.                                                                                                                                                               |3            |
# |12      |jelly    |An explosive mixture of nitroglycerine and nitrate absorbed onto a base of wood pulp.                                                                                                                                      |1            |
# |1,15    |racing   |To take part in a race (in the sense of a contest).                                                                                                                                                                        |2            |
# |5       |hot      |NULL                                                                                                                                                                                                                       |1            |
# |15      |poem     |A literary piece written in verse.                                                                                                                                                                                         |1            |
# |5       |water    |A substance (of molecular formula H₂O) found at room temperature and pressure as a clear liquid; it is present naturally as rain, and found in rivers, lakes and seas; its solid form is ice and its gaseous form is steam.|1            |
# |12,14   |dog      |A mammal, Canis familiaris or Canis lupus familiaris, that has been domesticated for thousands of years, of highly variable appearance due to human breeding.                                                              |2            |
# |1       |stuffing |To fill by packing or crowding something into; to cram with something; to load to excess.                                                                                                                                  |1            |
# |15      |mermaid  |A mythological creature with a woman's head and upper body, and a tail of a fish.                                                                                                                                          |1            |
# |14      |swimming |The act or art of sustaining and propelling the body in water.                                                                                                                                                             |1            |
# |15,7    |winner   |One who has won or often wins.                                                                                                                                                                                             |2            |
# |12      |snail    |Any of very many animals (either hermaphroditic or nonhermaphroditic), of the class Gastropoda, having a coiled shell.                                                                                                     |1            |
# |7       |rosemary |A shrub, Rosmarinus officinalis, that originates from Europe and Asia Minor and produces a fragrant herb used in cooking and perfumes.                                                                                     |1            |
# |5       |shell    |A hard external covering of an animal.                                                                                                                                                                                     |1            |
# |12,7    |butterfly|A flying insect of the order Lepidoptera, distinguished from moths by their diurnal activity and generally brighter colouring.                                                                                             |2            |
# ...
# |12      |jelly   |An explosive mixture of nitroglycerine and nitrate absorbed onto a base of wood pulp.                                                                                                                                      |1            |
# |1,15    |racing  |To take part in a race (in the sense of a contest).                                                                                                                                                                        |2            |
# |5,10    |hot     |NULL                                                                                                                                                                                                                       |2            |
# |15      |poem    |A literary piece written in verse.                                                                                                                                                                                         |1            |
# |5       |water   |A substance (of molecular formula H₂O) found at room temperature and pressure as a clear liquid; it is present naturally as rain, and found in rivers, lakes and seas; its solid form is ice and its gaseous form is steam.|1            |
# |12,14   |dog     |A mammal, Canis familiaris or Canis lupus familiaris, that has been domesticated for thousands of years, of highly variable appearance due to human breeding.                                                              |2            |
# |10      |science |A particular discipline or branch of learning, especially one dealing with measurable or systematic principles rather than intuition or natural ability.                                                                   |1            |
# |1       |stuffing|To fill by packing or crowding something into; to cram with something; to load to excess.                                                                                                                                  |1            |
# |15      |mermaid |A mythological creature with a woman's head and upper body, and a tail of a fish.                                                                                                                                          |1            |
# |14      |swimming|The act or art of sustaining and propelling the body in water.                                                                                                                                                             |1            |
# |15,7    |winner  |One who has won or often wins.                                                                                                                                                                                             |2            |
# |1,4     |beach   |The shore of a body of water, especially when sandy or pebbly.                                                                                                                                                             |2            |
# +--------+--------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------------+
# only showing top 20 rows
# -------------------------------------------
# Batch: 13
# -------------------------------------------
# +--------+--------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------------+
# |user_ids|word    |meaning                                                                                                                                                                                                                    |request_count|
# +--------+--------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------------+
# |4,7     |brownie |A small square piece of rich cake, usually made with chocolate.                                                                                                                                                            |2            |
# |3,1,14  |speed   |The state of moving quickly or the capacity for rapid motion; rapidity.                                                                                                                                                    |3            |
# |5,10    |coffee  |A beverage made by infusing the beans of the coffee plant in hot water.                                                                                                                                                    |2            |
# |3       |elephant|A mammal of the order Proboscidea, having a trunk, and two large ivory tusks jutting from the upper jaw.                                                                                                                   |1            |
# |4       |avocado |The large, usually yellowish-green or black, pulpy fruit of the avocado tree.                                                                                                                                              |1            |
# |1,6     |vacation|Freedom from some business or activity.                                                                                                                                                                                    |2            |
# |3,12,14 |computer|A person employed to perform computations; one who computes.                                                                                                                                                               |3            |
# |2       |kayak   |A type of small boat, covered over by a surface deck, powered by the occupant or occupants using a double-bladed paddle in a sitting position, from a hole in the surface deck                                             |1            |
# |12      |jelly   |An explosive mixture of nitroglycerine and nitrate absorbed onto a base of wood pulp.                                                                                                                                      |1            |
# |1,15    |racing  |To take part in a race (in the sense of a contest).                                                                                                                                                                        |2            |
# |5,10    |hot     |NULL                                                                                                                                                                                                                       |2            |
# |15      |poem    |A literary piece written in verse.                                                                                                                                                                                         |1            |
# |5       |water   |A substance (of molecular formula H₂O) found at room temperature and pressure as a clear liquid; it is present naturally as rain, and found in rivers, lakes and seas; its solid form is ice and its gaseous form is steam.|1            |
# |12,14   |dog     |A mammal, Canis familiaris or Canis lupus familiaris, that has been domesticated for thousands of years, of highly variable appearance due to human breeding.                                                              |2            |
# |10      |science |A particular discipline or branch of learning, especially one dealing with measurable or systematic principles rather than intuition or natural ability.                                                                   |1            |
# |1       |stuffing|To fill by packing or crowding something into; to cram with something; to load to excess.                                                                                                                                  |1            |
# |15      |mermaid |A mythological creature with a woman's head and upper body, and a tail of a fish.                                                                                                                                          |1            |
# |14      |swimming|The act or art of sustaining and propelling the body in water.                                                                                                                                                             |1            |
# |15,7    |winner  |One who has won or often wins.                                                                                                                                                                                             |2            |
# |1,4     |beach   |The shore of a body of water, especially when sandy or pebbly.                                                                                                                                                             |2            |
# +--------+--------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------------+
# only showing top 20 rows
#
# -------------------------------------------
# Batch: 14
# -------------------------------------------
# +--------+--------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------------+
# |user_ids|word    |meaning                                                                                                                                                                                                                    |request_count|
# +--------+--------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------------+
# |4,7     |brownie |A small square piece of rich cake, usually made with chocolate.                                                                                                                                                            |2            |
# |3,1,14  |speed   |The state of moving quickly or the capacity for rapid motion; rapidity.                                                                                                                                                    |3            |
# |5,10    |coffee  |A beverage made by infusing the beans of the coffee plant in hot water.                                                                                                                                                    |3            |
# |3       |elephant|A mammal of the order Proboscidea, having a trunk, and two large ivory tusks jutting from the upper jaw.                                                                                                                   |1            |
# |4       |avocado |The large, usually yellowish-green or black, pulpy fruit of the avocado tree.                                                                                                                                              |1            |
# |1,5,6   |vacation|Freedom from some business or activity.                                                                                                                                                                                    |3            |
# |3,12,14 |computer|A person employed to perform computations; one who computes.                                                                                                                                                               |3            |
# |2       |kayak   |A type of small boat, covered over by a surface deck, powered by the occupant or occupants using a double-bladed paddle in a sitting position, from a hole in the surface deck                                             |1            |
# |12      |jelly   |An explosive mixture of nitroglycerine and nitrate absorbed onto a base of wood pulp.                                                                                                                                      |1            |
# |1,15    |racing  |To take part in a race (in the sense of a contest).                                                                                                                                                                        |2            |
# |5,10    |hot     |NULL                                                                                                                                                                                                                       |2            |
# |15      |poem    |A literary piece written in verse.                                                                                                                                                                                         |1            |
# |5       |water   |A substance (of molecular formula H₂O) found at room temperature and pressure as a clear liquid; it is present naturally as rain, and found in rivers, lakes and seas; its solid form is ice and its gaseous form is steam.|2            |
# |12,14   |dog     |A mammal, Canis familiaris or Canis lupus familiaris, that has been domesticated for thousands of years, of highly variable appearance due to human breeding.                                                              |2            |
# |10      |science |A particular discipline or branch of learning, especially one dealing with measurable or systematic principles rather than intuition or natural ability.                                                                   |1            |
# |1       |stuffing|To fill by packing or crowding something into; to cram with something; to load to excess.                                                                                                                                  |1            |
# |15      |mermaid |A mythological creature with a woman's head and upper body, and a tail of a fish.                                                                                                                                          |1            |
# |14      |swimming|The act or art of sustaining and propelling the body in water.                                                                                                                                                             |1            |
# |15,7    |winner  |One who has won or often wins.                                                                                                                                                                                             |2            |
# |1,4     |beach   |The shore of a body of water, especially when sandy or pebbly.                                                                                                                                                             |2            |
# +--------+--------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------------+
# only showing top 20 rows
