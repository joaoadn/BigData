# %% [markdown]
# # EX7-STRUCT: SparkSQL aggregates, execution plan, and others
#
# Your assignment: complete the `TODO`'s and include also the **output of each cell**.
#
# #### You may need to read the [Dataframe API Documentation](https://spark.apache.org/docs/latest/api/python/reference/pyspark.sql/dataframe.html) to complete this lab.

# %% [markdown]
# ### Step 1: Download Bike Trip Data (GDrive)

# %%
import os
import gdown

# stations data
if not os.path.isfile('data/station-data.json'):
    id = "134kLURYaTZuj6SWrg1XvkQKQ30bf1X7I"
    gdown.download(id=id, output="data/")
    print("Stations data downloaded")
else:
    print("Stations data already downloaded")

# trips data
if not os.path.isfile('data/trip-data.json'):
    id = "1pX3WHi3R2n52zyo6swXxlOtVTgt_hOQG"
    gdown.download(id=id, output="data/")
    print("Trips data downloaded")
else:
    print("Trips data already downloaded")
# Out:
# Stations data already downloaded
# Trips data already downloaded

# %% [markdown]
# ### Step 2: Start Spark Session

# %%
from pyspark.sql import SparkSession

try:
    spark.stop()
except NameError:
    print("SparkContext not defined")

# local mode
spark = SparkSession.builder \
            .appName("Spark SQL basic example") \
            .master("local[*]") \
	    	.config("spark.some.config.option", "some-value") \
	    	.getOrCreate()

# cluster mode
#spark = SparkSession.builder \
#            .appName("Spark SQL basic example") \
#            .master("spark://spark:7077") \
#	    	.config("spark.some.config.option", "some-value") \
#	    	.getOrCreate()
# Out:
# SparkContext not defined
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 25/05/08 00:56:17 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 25/05/08 00:56:17 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.

# %% [markdown]
# ### Step 3: Read JSON files as dataframes

# %%
stations_df = spark.read.json('data/station-data.json')
stations_df.show()
# Out:
# +---------+------------+------------+---------+-----------+--------------------+----------+
# |dockcount|installation|    landmark|      lat|       long|                name|station_id|
# +---------+------------+------------+---------+-----------+--------------------+----------+
# |       27|  2013-08-06|    San Jose|37.329732|-121.901782|San Jose Diridon ...|         2|
# |       15|  2013-08-05|    San Jose|37.330698|-121.888979|San Jose Civic Ce...|         3|
# |       11|  2013-08-06|    San Jose|37.333988|-121.894902|Santa Clara at Al...|         4|
# |       19|  2013-08-05|    San Jose|37.331415|  -121.8932|    Adobe on Almaden|         5|
# |       15|  2013-08-07|    San Jose|37.336721|-121.894074|    San Pedro Square|         6|
# |       15|  2013-08-07|    San Jose|37.333798|-121.886943|Paseo de San Antonio|         7|
# |       15|  2013-08-05|    San Jose|37.330165|-121.885831| San Salvador at 1st|         8|
# |       15|  2013-08-05|    San Jose|37.348742|-121.894715|           Japantown|         9|
# |       15|  2013-08-06|    San Jose|37.337391|-121.886995|  San Jose City Hall|        10|
# |       19|  2013-08-06|    San Jose|37.335885| -121.88566|         MLK Library|        11|
# |       19|  2013-08-07|    San Jose|37.332808|-121.883891|SJSU 4th at San C...|        12|
# |       15|  2013-08-06|    San Jose|37.339301|-121.889937|       St James Park|        13|
# |       19|  2013-08-05|    San Jose|37.332692|-121.900084|Arena Green / SAP...|        14|
# |       15|  2013-08-07|    San Jose|37.333955|-121.877349|SJSU - San Salvad...|        16|
# |       15|  2013-08-12|Redwood City|37.481758|-122.226904|   Franklin at Maple|        21|
# |       25|  2013-08-15|Redwood City|37.486078|-122.232089|Redwood City Calt...|        22|
# |       15|  2013-08-15|Redwood City|37.487616|-122.229951|San Mateo County ...|        23|
# |       15|  2013-08-12|Redwood City|37.484219|-122.227424|Redwood City Publ...|        24|
# |       15|  2013-08-12|Redwood City| 37.48537|-122.203288|Stanford in Redwo...|        25|
# |       15|  2013-08-12|Redwood City|37.487682|-122.223492|Redwood City Medi...|        26|
# +---------+------------+------------+---------+-----------+--------------------+----------+
# only showing top 20 rows

# %%
trips_df = spark.read.json('data/trip-data.json').repartition(9)
trips_df.show()
# Out:
# +-------+--------+--------------------+--------------------+------------+--------------------+--------------------+--------------+---------------+-------+--------+
# |bike_id|duration|            end_date|         end_station|end_terminal|          start_date|       start_station|start_terminal|subscriber_type|trip_id|zip_code|
# +-------+--------+--------------------+--------------------+------------+--------------------+--------------------+--------------+---------------+-------+--------+
# |    553|     698|2015-08-26T00:09:...|     Spear at Folsom|          49|2015-08-26T00:08:...|San Francisco Cal...|            69|     Subscriber| 905821|   94040|
# |    292|     628|2015-08-20T00:09:...|  Powell Street BART|          39|2015-08-20T00:09:...|     Townsend at 7th|            65|     Subscriber| 898176|   94107|
# |    506|     503|2015-08-28T00:08:...|       2nd at Folsom|          62|2015-08-28T00:08:...|Harry Bridges Pla...|            50|     Subscriber| 909314|   94558|
# |    520|     444|2015-08-25T00:10:...|   2nd at South Park|          64|2015-08-25T00:09:...|Temporary Transba...|            55|     Subscriber| 904161|   94610|
# |    340|     305|2015-08-21T00:11:...|Civic Center BART...|          72|2015-08-21T00:11:...|South Van Ness at...|            66|     Subscriber| 900036|   94702|
# |    585|     766|2015-08-29T00:11:...|     Spear at Folsom|          49|2015-08-29T00:11:...|       5th at Howard|            57|       Customer| 910815|   94558|
# |    355|    4323|2015-08-29T00:08:...|Embarcadero at Va...|          48|2015-08-29T00:07:...|Embarcadero at Va...|            48|       Customer| 910713|    NULL|
# |    877|     419|2015-08-20T00:13:...|San Francisco Cal...|          69|2015-08-20T00:13:...|San Francisco Cal...|            69|       Customer| 898437|    2138|
# |    404|     381|2015-08-28T00:09:...|Broadway St at Ba...|          82|2015-08-28T00:09:...|   Steuart at Market|            74|     Subscriber| 909603|   94556|
# |    147|    1068|2015-08-23T00:21:...|Castro Street and...|          32|2015-08-23T00:20:...|Mountain View Cal...|            28|     Subscriber| 901801|   95032|
# |    275|     537|2015-08-26T00:17:...|   Steuart at Market|          74|2015-08-26T00:17:...|     2nd at Townsend|            61|     Subscriber| 906853|   94110|
# |    578|     353|2015-08-23T00:17:...|San Francisco Cal...|          69|2015-08-23T00:17:...|       5th at Howard|            57|       Customer| 901719|   94148|
# |    563|     810|2015-08-28T00:17:...|Embarcadero at Sa...|          60|2015-08-28T00:17:...|San Francisco Cal...|            70|     Subscriber| 910364|   94111|
# |    212|     506|2015-08-20T00:08:...|       Market at 4th|          76|2015-08-20T00:08:...|     Spear at Folsom|            49|     Subscriber| 897997|   94105|
# |     96|     357|2015-08-27T00:09:...|     Clay at Battery|          41|2015-08-27T00:09:...|Mechanics Plaza (...|            75|     Subscriber| 907893|   94704|
# |    534|     567|2015-08-28T00:16:...|San Francisco Cal...|          70|2015-08-28T00:16:...|Temporary Transba...|            55|     Subscriber| 910149|   95014|
# |    636|     411|2015-08-18T00:08:...|Yerba Buena Cente...|          68|2015-08-18T00:08:...|San Francisco Cal...|            69|     Subscriber| 894385|   94107|
# |    404|     359|2015-08-28T00:11:...|   Market at Sansome|          77|2015-08-28T00:11:...|Broadway St at Ba...|            82|     Subscriber| 909875|   94109|
# |    537|     747|2015-08-25T00:14:...|Embarcadero at Sa...|          60|2015-08-25T00:14:...|Embarcadero at Br...|            54|     Subscriber| 904476|   94105|
# |    636|     611|2015-08-17T00:17:...|      Market at 10th|          67|2015-08-17T00:17:...|     Townsend at 7th|            65|     Subscriber| 893576|   94551|
# +-------+--------+--------------------+--------------------+------------+--------------------+--------------------+--------------+---------------+-------+--------+
# only showing top 20 rows

# %% [markdown]
# ### Step 4: Follow the [groupBy tutorial on SparkByExample](https://sparkbyexamples.com/pyspark/pyspark-groupby-explained-with-example/) `#TODO`
# 1. Reproduce in this notebook each example on the tutorial page, **however, using the stations and trips dataframes instead**
# 2. The objective is for you to take practice on each operator and hence, you may choose the specifics -- column, or columns, queries, etc.

# %%
# Example 1: Group by a single column and count
stations_count = trips_df.groupBy("start_station").count()
stations_count.show()

# Example 2: Group by multiple columns
station_zip_count = trips_df.groupBy("start_station", "zip_code").count()
station_zip_count.show()

# Example 3: Group by a column and aggregate using sum
total_duration = trips_df.groupBy("start_station").sum("duration")
total_duration.show()

# Example 4: Group by a column and aggregate using avg
average_duration = trips_df.groupBy("start_station").avg("duration")
average_duration.show()

# Example 5: Group by a column and aggregate using min
min_duration = trips_df.groupBy("start_station").min("duration")
min_duration.show()

# Example 6: Group by a column and aggregate using max
max_duration = trips_df.groupBy("start_station").max("duration")
max_duration.show()

# Example 7: Group by a column and use multiple aggregations
station_duration_stats = trips_df.groupBy("start_station").agg(
    {"duration": "sum", "duration": "avg", "duration": "min", "duration": "max"}
)
station_duration_stats.show()
# Out:
# +--------------------+-----+
# |       start_station|count|
# +--------------------+-----+
# |       2nd at Folsom| 7999|
# |California Ave Ca...|  400|
# |Powell at Post (U...| 6425|
# | Golden Gate at Polk| 3646|
# |Yerba Buena Cente...| 5523|
# |   Market at Sansome|11431|
# |         MLK Library| 1099|
# |     Spear at Folsom| 5574|
# |           Japantown|  885|
# |Commercial at Mon...| 6014|
# |Paseo de San Antonio|  856|
# | San Salvador at 1st|  495|
# |Rengstorff Avenue...|  501|
# |     Townsend at 7th|13752|
# |Civic Center BART...| 7760|
# |         Ryland Park| 1120|
# |San Jose Diridon ...| 4968|
# |San Jose Civic Ce...|  774|
# |          Mezes Park|  212|
# |SJSU - San Salvad...|  494|
# +--------------------+-----+
# only showing top 20 rows
#
# +--------------------+--------+-----+
# |       start_station|zip_code|count|
# +--------------------+--------+-----+
# |   Market at Sansome|   94544|   69|
# |           Japantown|   95112|  443|
# |   2nd at South Park|   94102|  125|
# |Broadway St at Ba...|   94132|  246|
# |Embarcadero at Fo...|   94403|   49|
# |Santa Clara Count...|   95110|  149|
# |       Howard at 2nd|   94063|  148|
# |   Market at Sansome|   94941|   40|
# |Civic Center BART...|   54500|    1|
# |San Francisco Cal...|   93401|   50|
# |    Davis at Jackson|   94610|   15|
# |   Steuart at Market|   95125|    1|
# |     2nd at Townsend|   92119|    2|
# |University and Em...|   90037|    2|
# |Grant Avenue at C...|   94549|    7|
# |       Howard at 2nd|   94904|    1|
# |Washington at Kearny|   94945|    1|
# |     Spear at Folsom|   94108|    9|
# |     Clay at Battery|   94904|    7|
# |Grant Avenue at C...|   44122|    2|
# +--------------------+--------+-----+
# only showing top 20 rows
#
# +--------------------+-------------+
# |       start_station|sum(duration)|
# +--------------------+-------------+
# |       2nd at Folsom|      4346624|
# |California Ave Ca...|      1603842|
# |Powell at Post (U...|      8429671|
# | Golden Gate at Polk|      4146900|
# |Yerba Buena Cente...|      4963300|
# |   Market at Sansome|     10394882|
# |     Spear at Folsom|      4602247|
# |         MLK Library|      1200026|
# |           Japantown|      2097184|
# |Commercial at Mon...|      4823682|
# |Paseo de San Antonio|      1296427|
# | San Salvador at 1st|       895792|
# |Rengstorff Avenue...|       823549|
# |     Townsend at 7th|      8610581|
# |Civic Center BART...|      8045076|
# |         Ryland Park|       943787|
# |San Jose Diridon ...|      4393575|
# |San Jose Civic Ce...|      4224522|
# |          Mezes Park|       481441|
# |SJSU - San Salvad...|       803760|
# +--------------------+-------------+
# only showing top 20 rows
#
# +--------------------+------------------+
# |       start_station|     avg(duration)|
# +--------------------+------------------+
# |       2nd at Folsom| 543.3959244905614|
# |California Ave Ca...|          4009.605|
# |Powell at Post (U...|1312.0110505836576|
# | Golden Gate at Polk|1137.3834339001646|
# |Yerba Buena Cente...| 898.6601484700344|
# |   Market at Sansome| 909.3589362260519|
# |     Spear at Folsom| 825.6632579834948|
# |         MLK Library|1091.9253867151956|
# |           Japantown|2369.6994350282484|
# |Commercial at Mon...|  802.075490522115|
# |Paseo de San Antonio| 1514.517523364486|
# | San Salvador at 1st| 1809.680808080808|
# |Rengstorff Avenue...| 1643.810379241517|
# |     Townsend at 7th| 626.1329988365329|
# |Civic Center BART...|1036.7365979381443|
# |         Ryland Park| 842.6669642857142|
# |San Jose Diridon ...|           884.375|
# |San Jose Civic Ce...| 5458.038759689923|
# |          Mezes Park| 2270.948113207547|
# |SJSU - San Salvad...|1627.0445344129555|
# +--------------------+------------------+
# only showing top 20 rows
#
# +--------------------+-------------+
# |       start_station|min(duration)|
# +--------------------+-------------+
# |       2nd at Folsom|           61|
# |California Ave Ca...|           82|
# |Powell at Post (U...|           65|
# | Golden Gate at Polk|           60|
# |Yerba Buena Cente...|           60|
# |   Market at Sansome|           60|
# |     Spear at Folsom|           60|
# |         MLK Library|           66|
# |           Japantown|          120|
# |Commercial at Mon...|           62|
# |Paseo de San Antonio|           65|
# | San Salvador at 1st|           83|
# |Rengstorff Avenue...|           68|
# |     Townsend at 7th|           61|
# |Civic Center BART...|           60|
# |         Ryland Park|           65|
# |San Jose Diridon ...|           62|
# |San Jose Civic Ce...|           74|
# |          Mezes Park|          116|
# |SJSU - San Salvad...|           63|
# +--------------------+-------------+
# only showing top 20 rows
#
# +--------------------+-------------+
# |       start_station|max(duration)|
# +--------------------+-------------+
# |       2nd at Folsom|        67251|
# |California Ave Ca...|       110571|
# |Powell at Post (U...|       217429|
# | Golden Gate at Polk|        73103|
# |Yerba Buena Cente...|       154979|
# |   Market at Sansome|      2137000|
# |     Spear at Folsom|       125909|
# |         MLK Library|       131443|
# |           Japantown|       489435|
# |Commercial at Mon...|        95830|
# |Paseo de San Antonio|       288430|
# | San Salvador at 1st|       123337|
# |Rengstorff Avenue...|       150567|
# |     Townsend at 7th|        82585|
# |Civic Center BART...|       207475|
# |         Ryland Park|        91749|
# |San Jose Diridon ...|       531240|
# |San Jose Civic Ce...|       655939|
# |          Mezes Park|       119940|
# |SJSU - San Salvad...|       140544|
# +--------------------+-------------+
# only showing top 20 rows
#
# +--------------------+-------------+
# |       start_station|max(duration)|
# +--------------------+-------------+
# |       2nd at Folsom|        67251|
# |California Ave Ca...|       110571|
# |Powell at Post (U...|       217429|
# | Golden Gate at Polk|        73103|
# |Yerba Buena Cente...|       154979|
# |   Market at Sansome|      2137000|
# |     Spear at Folsom|       125909|
# |         MLK Library|       131443|
# |           Japantown|       489435|
# |Commercial at Mon...|        95830|
# |Paseo de San Antonio|       288430|
# | San Salvador at 1st|       123337|
# |Rengstorff Avenue...|       150567|
# |     Townsend at 7th|        82585|
# |Civic Center BART...|       207475|
# |         Ryland Park|        91749|
# |San Jose Diridon ...|       531240|
# |San Jose Civic Ce...|       655939|
# |          Mezes Park|       119940|
# |SJSU - San Salvad...|       140544|
# +--------------------+-------------+
# only showing top 20 rows

# %% [markdown]
# ### Step 5: In SparkSQL it is also possible to create *User-Defined Functions (UDF)* to use within queries
# 1. See how this can be accomplished in [this page](https://sparkbyexamples.com/pyspark/pyspark-udf-user-defined-function/)
# 2. Show an example using the dataframes loaded in this notebook

# %%
from pyspark.sql.functions import udf
from pyspark.sql.types import IntegerType

# Step 1: Define a UDF that will add 10 to the duration of the trips
def add_ten_to_duration(duration):
    return duration + 10 if duration is not None else None

# Register the UDF
add_ten_to_duration_udf = udf(add_ten_to_duration, IntegerType())

# Step 2: Use the UDF within a Spark SQL query or DataFrame transformation
trips_with_adjusted_duration = trips_df.withColumn(
    "adjusted_duration", add_ten_to_duration_udf(col("duration"))
)

# Step 3: Show the result
trips_with_adjusted_duration.select("start_station", "duration", "adjusted_duration").show(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 13
#       9 add_ten_to_duration_udf = udf(add_ten_to_duration, IntegerType())
#      11 # Step 2: Use the UDF within a Spark SQL query or DataFrame transformation
#      12 trips_with_adjusted_duration = trips_df.withColumn(
# ---> 13     "adjusted_duration", add_ten_to_duration_udf(col("duration"))
#      14 )
#      16 # Step 3: Show the result
#      17 trips_with_adjusted_duration.select("start_station", "duration", "adjusted_duration").show(10)
#
# NameError: name 'col' is not defined

# %% [markdown]
# ### Step 6: Take two query examples from the previous steps and `explain` their execution plans
#
# *Syntax:* `df.explain(True)`

# %%
# Example 1: Group by a single column and count
stations_count = trips_df.groupBy("start_station").count()

# Explain the execution plan for this query
stations_count.explain(True)

# Example 2: Group by a column and aggregate using sum
total_duration = trips_df.groupBy("start_station").sum("duration")

# Explain the execution plan for this query
total_duration.explain(True)
# Out:
# == Parsed Logical Plan ==
# 'Aggregate ['start_station], ['start_station, count(1) AS count#378L]
# +- Repartition 9, true
#    +- Relation [bike_id#67L,duration#68L,end_date#69,end_station#70,end_terminal#71L,start_date#72,start_station#73,start_terminal#74L,subscriber_type#75,trip_id#76L,zip_code#77L] json
#
# == Analyzed Logical Plan ==
# start_station: string, count: bigint
# Aggregate [start_station#73], [start_station#73, count(1) AS count#378L]
# +- Repartition 9, true
#    +- Relation [bike_id#67L,duration#68L,end_date#69,end_station#70,end_terminal#71L,start_date#72,start_station#73,start_terminal#74L,subscriber_type#75,trip_id#76L,zip_code#77L] json
#
# == Optimized Logical Plan ==
# Aggregate [start_station#73], [start_station#73, count(1) AS count#378L]
# +- Repartition 9, true
#    +- Project [start_station#73]
#       +- Relation [bike_id#67L,duration#68L,end_date#69,end_station#70,end_terminal#71L,start_date#72,start_station#73,start_terminal#74L,subscriber_type#75,trip_id#76L,zip_code#77L] json
#
# == Physical Plan ==
# AdaptiveSparkPlan isFinalPlan=false
# +- HashAggregate(keys=[start_station#73], functions=[count(1)], output=[start_station#73, count#378L])
#    +- Exchange hashpartitioning(start_station#73, 200), ENSURE_REQUIREMENTS, [plan_id=553]
#       +- HashAggregate(keys=[start_station#73], functions=[partial_count(1)], output=[start_station#73, count#382L])
#          +- Exchange RoundRobinPartitioning(9), REPARTITION_BY_NUM, [plan_id=549]
#             +- FileScan json [start_station#73] Batched: false, DataFilters: [], Format: JSON, Location: InMemoryFileIndex(1 paths)[file:/app/hostdir/data/trip-data.json], PartitionFilters: [], PushedFilters: [], ReadSchema: struct<start_station:string>
#
# == Parsed Logical Plan ==
# 'Aggregate ['start_station], ['start_station, sum(duration#68L) AS sum(duration)#395L]
# +- Repartition 9, true
#    +- Relation [bike_id#67L,duration#68L,end_date#69,end_station#70,end_terminal#71L,start_date#72,start_station#73,start_terminal#74L,subscriber_type#75,trip_id#76L,zip_code#77L] json
#
# == Analyzed Logical Plan ==
# start_station: string, sum(duration): bigint
# Aggregate [start_station#73], [start_station#73, sum(duration#68L) AS sum(duration)#395L]
# +- Repartition 9, true
#    +- Relation [bike_id#67L,duration#68L,end_date#69,end_station#70,end_terminal#71L,start_date#72,start_station#73,start_terminal#74L,subscriber_type#75,trip_id#76L,zip_code#77L] json
#
# == Optimized Logical Plan ==
# Aggregate [start_station#73], [start_station#73, sum(duration#68L) AS sum(duration)#395L]
# +- Repartition 9, true
#    +- Project [duration#68L, start_station#73]
#       +- Relation [bike_id#67L,duration#68L,end_date#69,end_station#70,end_terminal#71L,start_date#72,start_station#73,start_terminal#74L,subscriber_type#75,trip_id#76L,zip_code#77L] json
#
# == Physical Plan ==
# AdaptiveSparkPlan isFinalPlan=false
# +- HashAggregate(keys=[start_station#73], functions=[sum(duration#68L)], output=[start_station#73, sum(duration)#395L])
#    +- Exchange hashpartitioning(start_station#73, 200), ENSURE_REQUIREMENTS, [plan_id=570]
#       +- HashAggregate(keys=[start_station#73], functions=[partial_sum(duration#68L)], output=[start_station#73, sum#399L])
#          +- Exchange RoundRobinPartitioning(9), REPARTITION_BY_NUM, [plan_id=566]
#             +- FileScan json [duration#68L,start_station#73] Batched: false, DataFilters: [], Format: JSON, Location: InMemoryFileIndex(1 paths)[file:/app/hostdir/data/trip-data.json], PartitionFilters: [], PushedFilters: [], ReadSchema: struct<duration:bigint,start_station:string>
